# %%
import pandas as pd 
data=pd.read_csv('C:\\Users\\pc\\python-basics\\Example1_pandas.csv')
data
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.shape
# Out:
# (10, 5)

# %%
data.head(4)
# Out:
#     ID       Name    Place  Gender   Age
# 0  101       Jaya   London  Female  23.0
# 1  102      Jeena  NewYork  Female   NaN
# 2  103      Elena   London  Female  22.0
# 3  104  Katherine  NewYork  Female  25.0

# %%
data.tail(6)
# Out:
#     ID    Name     Place  Gender   Age
# 4  105   Damon  Virginia    Male  45.0
# 5  106  Bonnie   Georgia  Female   NaN
# 6  107    Joey   NewYork    Male  30.0
# 7  108   Hessa       NaN  Female  21.0
# 8  109    Ayan     Saudi    Male  29.0
# 9  110    Robb       NaN    Male   NaN

# %%
data.columns
# Out:
# Index(['ID', 'Name', 'Place', 'Gender', 'Age'], dtype='object')

# %%
data['Age']
# Out:
# 0    23.0
# 1     NaN
# 2    22.0
# 3    25.0
# 4    45.0
# 5     NaN
# 6    30.0
# 7    21.0
# 8    29.0
# 9     NaN
# Name: Age, dtype: float64

# %%
data[['Age','Name','ID']]
# Out:
#     Age       Name   ID
# 0  23.0       Jaya  101
# 1   NaN      Jeena  102
# 2  22.0      Elena  103
# 3  25.0  Katherine  104
# 4  45.0      Damon  105
# 5   NaN     Bonnie  106
# 6  30.0       Joey  107
# 7  21.0      Hessa  108
# 8  29.0       Ayan  109
# 9   NaN       Robb  110

# %%
new_data=data.drop('Age',axis=1)
new_data
# Out:
#     ID       Name     Place  Gender
# 0  101       Jaya    London  Female
# 1  102      Jeena   NewYork  Female
# 2  103      Elena    London  Female
# 3  104  Katherine   NewYork  Female
# 4  105      Damon  Virginia    Male
# 5  106     Bonnie   Georgia  Female
# 6  107       Joey   NewYork    Male
# 7  108      Hessa       NaN  Female
# 8  109       Ayan     Saudi    Male
# 9  110       Robb       NaN    Male

# %%
data.sort_values('Age')
# Out:
#     ID       Name     Place  Gender   Age
# 7  108      Hessa       NaN  Female  21.0
# 2  103      Elena    London  Female  22.0
# 0  101       Jaya    London  Female  23.0
# 3  104  Katherine   NewYork  Female  25.0
# 8  109       Ayan     Saudi    Male  29.0
# 6  107       Joey   NewYork    Male  30.0
# 4  105      Damon  Virginia    Male  45.0
# 1  102      Jeena   NewYork  Female   NaN
# 5  106     Bonnie   Georgia  Female   NaN
# 9  110       Robb       NaN    Male   NaN

# %%
data.sort_values('Name')
# Out:
#     ID       Name     Place  Gender   Age
# 8  109       Ayan     Saudi    Male  29.0
# 5  106     Bonnie   Georgia  Female   NaN
# 4  105      Damon  Virginia    Male  45.0
# 2  103      Elena    London  Female  22.0
# 7  108      Hessa       NaN  Female  21.0
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 3  104  Katherine   NewYork  Female  25.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
data_index=data.set_index('ID')
data_index
# Out:
#           Name     Place  Gender   Age
# ID
# 101       Jaya    London  Female  23.0
# 102      Jeena   NewYork  Female   NaN
# 103      Elena    London  Female  22.0
# 104  Katherine   NewYork  Female  25.0
# 105      Damon  Virginia    Male  45.0
# 106     Bonnie   Georgia  Female   NaN
# 107       Joey   NewYork    Male  30.0
# 108      Hessa       NaN  Female  21.0
# 109       Ayan     Saudi    Male  29.0
# 110       Robb       NaN    Male   NaN

# %%
data.loc[4]
# Out:
# ID             105
# Name         Damon
# Place     Virginia
# Gender        Male
# Age           45.0
# Name: 4, dtype: object

# %%
new=data.set_index('Name')
new
# Out:
#             ID     Place  Gender   Age
# Name
# Jaya       101    London  Female  23.0
# Jeena      102   NewYork  Female   NaN
# Elena      103    London  Female  22.0
# Katherine  104   NewYork  Female  25.0
# Damon      105  Virginia    Male  45.0
# Bonnie     106   Georgia  Female   NaN
# Joey       107   NewYork    Male  30.0
# Hessa      108       NaN  Female  21.0
# Ayan       109     Saudi    Male  29.0
# Robb       110       NaN    Male   NaN

# %%
new.loc['Ayan']
# Out:
# ID          109
# Place     Saudi
# Gender     Male
# Age        29.0
# Name: Ayan, dtype: object

# %%
data.iloc[3]
# Out:
# ID              104
# Name      Katherine
# Place       NewYork
# Gender       Female
# Age            25.0
# Name: 3, dtype: object

# %%
data.copy()
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
ds=data.drop('Age',axis=1)
ds
# Out:
#     ID       Name     Place  Gender
# 0  101       Jaya    London  Female
# 1  102      Jeena   NewYork  Female
# 2  103      Elena    London  Female
# 3  104  Katherine   NewYork  Female
# 4  105      Damon  Virginia    Male
# 5  106     Bonnie   Georgia  Female
# 6  107       Joey   NewYork    Male
# 7  108      Hessa       NaN  Female
# 8  109       Ayan     Saudi    Male
# 9  110       Robb       NaN    Male

# %%
data.Place.unique()
# Out:
# array(['London', 'NewYork', 'Virginia', 'Georgia', nan, 'Saudi'],
#       dtype=object)

# %%
data.Place.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      London
# 1     NewYork
# 2      London
# 3     NewYork
# 4    Virginia
# 5     Georgia
# 6     NewYork
# 7         NaN
# 8       Saudi
# 9         NaN
# Name: Place, dtype: object>

# %%
for i in data:
    print(i)
# Out:
# ID
# Name
# Place
# Gender
# Age

# %%
for columns,values in data.items():
    print(columns)
    print(values)
# Out:
# ID
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: ID, dtype: int64
# Name
# 0         Jaya
# 1        Jeena
# 2        Elena
# 3    Katherine
# 4        Damon
# 5       Bonnie
# 6         Joey
# 7        Hessa
# 8         Ayan
# 9         Robb
# Name: Name, dtype: object
# Place
# 0      London
# 1     NewYork
# 2      London
# 3     NewYork
# 4    Virginia
# 5     Georgia
# 6     NewYork
# 7         NaN
# 8       Saudi
# 9         NaN
# Name: Place, dtype: object
# Gender
# 0    Female
# 1    Female
# 2    Female
# 3    Female
# 4      Male
# 5    Female
# 6      Male
# 7    Female
# 8      Male
# 9      Male
# Name: Gender, dtype: object
# Age
# 0    23.0
# 1     NaN
# 2    22.0
# 3    25.0
# 4    45.0
# 5     NaN
# 6    30.0
# 7    21.0
# 8    29.0
# 9     NaN
# Name: Age, dtype: float64

# %%
for index,row in data.iterrows():
    print('row:',index)
    print(row)
# Out:
# row: 0
# ID           101
# Name        Jaya
# Place     London
# Gender    Female
# Age         23.0
# Name: 0, dtype: object
# row: 1
# ID            102
# Name        Jeena
# Place     NewYork
# Gender     Female
# Age           NaN
# Name: 1, dtype: object
# row: 2
# ID           103
# Name       Elena
# Place     London
# Gender    Female
# Age         22.0
# Name: 2, dtype: object
# row: 3
# ID              104
# Name      Katherine
# Place       NewYork
# Gender       Female
# Age            25.0
# Name: 3, dtype: object
# row: 4
# ID             105
# Name         Damon
# Place     Virginia
# Gender        Male
# Age           45.0
# Name: 4, dtype: object
# row: 5
# ID            106
# Name       Bonnie
# Place     Georgia
# Gender     Female
# Age           NaN
# Name: 5, dtype: object
# row: 6
# ID            107
# Name         Joey
# Place     NewYork
# Gender       Male
# Age          30.0
# Name: 6, dtype: object
# row: 7
# ID           108
# Name       Hessa
# ...

# %%
data[1:4]
# Out:
#     ID       Name    Place  Gender   Age
# 1  102      Jeena  NewYork  Female   NaN
# 2  103      Elena   London  Female  22.0
# 3  104  Katherine  NewYork  Female  25.0

# %%
data[1:4:2]
# Out:
#     ID       Name    Place  Gender   Age
# 1  102      Jeena  NewYork  Female   NaN
# 3  104  Katherine  NewYork  Female  25.0

# %%
data[['Name','Place']][1:4]
# Out:
#         Name    Place
# 1      Jeena  NewYork
# 2      Elena   London
# 3  Katherine  NewYork

# %%
data.copy()
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.Age.max()
# Out:
# 45.0

# %%
data.Age.min()
# Out:
# 21.0

# %%
data.Age.sum()
# Out:
# 195.0

# %%
data.Age.mean()
# Out:
# 27.857142857142858

# %%
data.Age.std()
# Out:
# 8.295150620062532

# %%
data.describe()
# Out:
#               ID        Age
# count   10.00000   7.000000
# mean   105.50000  27.857143
# std      3.02765   8.295151
# min    101.00000  21.000000
# 25%    103.25000  22.500000
# 50%    105.50000  25.000000
# 75%    107.75000  29.500000
# max    110.00000  45.000000

# %%
data[data['Age']>30]
# Out:
#     ID   Name     Place Gender   Age
# 4  105  Damon  Virginia   Male  45.0

# %%
data['Name'][data.Age==data.Age.min()]
# Out:
# 7    Hessa
# Name: Name, dtype: object

# %%
data.copy()
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.isna()
# Out:
#       ID   Name  Place  Gender    Age
# 0  False  False  False   False  False
# 1  False  False  False   False   True
# 2  False  False  False   False  False
# 3  False  False  False   False  False
# 4  False  False  False   False  False
# 5  False  False  False   False   True
# 6  False  False  False   False  False
# 7  False  False   True   False  False
# 8  False  False  False   False  False
# 9  False  False   True   False   True

# %%
data.isna().sum()
# Out:
# ID        0
# Name      0
# Place     2
# Gender    0
# Age       3
# dtype: int64

# %%
new_data=data.fillna(0)
new_data
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   0.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   0.0
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa         0  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb         0    Male   0.0

# %%
avrg=data['Age'].mean()
data.fillna(avrg)
# Out:
#     ID       Name      Place  Gender        Age
# 0  101       Jaya     London  Female  23.000000
# 1  102      Jeena    NewYork  Female  27.857143
# 2  103      Elena     London  Female  22.000000
# 3  104  Katherine    NewYork  Female  25.000000
# 4  105      Damon   Virginia    Male  45.000000
# 5  106     Bonnie    Georgia  Female  27.857143
# 6  107       Joey    NewYork    Male  30.000000
# 7  108      Hessa  27.857143  Female  21.000000
# 8  109       Ayan      Saudi    Male  29.000000
# 9  110       Robb  27.857143    Male  27.857143

# %%
data.fillna(method='ffill')
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3396\1844443866.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill')
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female  23.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female  45.0
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa   NewYork  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb     Saudi    Male  29.0

# %%
data.fillna(method='bfill')
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3396\1397359497.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='bfill')
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female  22.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female  30.0
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa     Saudi  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.bfill()
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female  22.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female  30.0
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa     Saudi  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.interpolate()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3396\982976692.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   data.interpolate()
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female  22.5
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female  37.5
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male  29.0

# %%
data.dropna()
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 6  107       Joey   NewYork    Male  30.0
# 8  109       Ayan     Saudi    Male  29.0

# %%
data.dropna(how='all')
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 1  102      Jeena   NewYork  Female   NaN
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 5  106     Bonnie   Georgia  Female   NaN
# 6  107       Joey   NewYork    Male  30.0
# 7  108      Hessa       NaN  Female  21.0
# 8  109       Ayan     Saudi    Male  29.0
# 9  110       Robb       NaN    Male   NaN

# %%
data.dropna(how='any')
# Out:
#     ID       Name     Place  Gender   Age
# 0  101       Jaya    London  Female  23.0
# 2  103      Elena    London  Female  22.0
# 3  104  Katherine   NewYork  Female  25.0
# 4  105      Damon  Virginia    Male  45.0
# 6  107       Joey   NewYork    Male  30.0
# 8  109       Ayan     Saudi    Male  29.0

# %% [markdown]
# PANDAS QUESTIONS

# %%
import pandas as pd 
import numpy as np 

sales_data={'OrderID': [1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,
1011,1012,1013,1014,1015,1016,1017,1018,1019,1020],
'Date': ['2024-01-05','2024-01-12','2024-02-03','2024-02-18',
'2024-03-07','2024-03-22','2024-04-10','2024-04-25',
'2024-05-08','2024-05-19','2024-06-02','2024-06-15',
'2024-07-04','2024-07-20','2024-08-11','2024-08-28',
'2024-09-06','2024-09-21','2024-10-14','2024-10-30'],
'Product': ['Laptop','Phone','Tablet','Laptop','Monitor','Phone',
'Tablet','Laptop','Keyboard','Monitor','Phone','Laptop',
'Tablet','Monitor','Phone','Laptop','Keyboard','Tablet',
'Phone','Monitor'],
'Category': ['Electronics','Electronics','Electronics','Electronics',
'Electronics','Electronics','Electronics','Electronics',
'Accessories','Electronics','Electronics','Electronics',
'Electronics','Electronics','Electronics','Electronics',
'Accessories','Electronics','Electronics','Electronics'],
'Region': ['North','South','East','West','North','South','East',
'West','North','South','East','West','North','South',
'East','West','North','South','East','West'],
'Salesperson':['Alice','Bob','Charlie','Diana','Alice','Bob',
'Charlie','Diana','Alice','Bob','Charlie','Diana',
'Alice','Bob','Charlie','Diana','Alice','Bob',
'Charlie','Diana'],
'Units': [2,5,3,1,2,4,6,1,10,3,7,2,4,2,5,1,8,3,6,2],
'UnitPrice': [999.99,499.99,349.99,999.99,399.99,499.99,349.99,
999.99,49.99,399.99,499.99,999.99,349.99,399.99,
499.99,999.99,49.99,349.99,499.99,399.99],
'Revenue': [1999.98,2499.95,1049.97,999.99,799.98,1999.96,
2099.94,999.99,499.90,1199.97,3499.93,1999.98,
1399.96,799.98,2499.95,999.99,399.92,1049.97,
2999.94,799.98],
'Discount': [0.05,0.10,0.00,0.15,0.05,0.10,0.00,0.15,
0.00,0.05,0.10,0.05,0.00,0.05,0.10,0.15,
0.00,0.00,0.10,0.05],
'Rating': [4.5,3.8,4.2,None,4.0,3.5,4.8,None,4.1,3.9,
4.6,4.3,4.7,None,3.6,4.4,4.0,4.2,3.7,4.5]
}
sales=pd.DataFrame(sales_data)
sales['Date']=pd.to_datetime(sales['Date'])
sales
# Out:
#     OrderID       Date   Product     Category Region Salesperson  Units  \
# 0      1001 2024-01-05    Laptop  Electronics  North       Alice      2
# 1      1002 2024-01-12     Phone  Electronics  South         Bob      5
# 2      1003 2024-02-03    Tablet  Electronics   East     Charlie      3
# 3      1004 2024-02-18    Laptop  Electronics   West       Diana      1
# 4      1005 2024-03-07   Monitor  Electronics  North       Alice      2
# 5      1006 2024-03-22     Phone  Electronics  South         Bob      4
# 6      1007 2024-04-10    Tablet  Electronics   East     Charlie      6
# 7      1008 2024-04-25    Laptop  Electronics   West       Diana      1
# 8      1009 2024-05-08  Keyboard  Accessories  North       Alice     10
# 9      1010 2024-05-19   Monitor  Electronics  South         Bob      3
# 10     1011 2024-06-02     Phone  Electronics   East     Charlie      7
# 11     1012 2024-06-15    Laptop  Electronics   West       Diana      2
# ...

# %%
print (sales.head(5))
# Out:
#    OrderID       Date  Product     Category Region Salesperson  Units  \
# 0     1001 2024-01-05   Laptop  Electronics  North       Alice      2
# 1     1002 2024-01-12    Phone  Electronics  South         Bob      5
# 2     1003 2024-02-03   Tablet  Electronics   East     Charlie      3
# 3     1004 2024-02-18   Laptop  Electronics   West       Diana      1
# 4     1005 2024-03-07  Monitor  Electronics  North       Alice      2
#
#    UnitPrice  Revenue  Discount  Rating
# 0     999.99  1999.98      0.05     4.5
# 1     499.99  2499.95      0.10     3.8
# 2     349.99  1049.97      0.00     4.2
# 3     999.99   999.99      0.15     NaN
# 4     399.99   799.98      0.05     4.0

# %%
print(sales.tail(3))
# Out:
#     OrderID       Date  Product     Category Region Salesperson  Units  \
# 17     1018 2024-09-21   Tablet  Electronics  South         Bob      3
# 18     1019 2024-10-14    Phone  Electronics   East     Charlie      6
# 19     1020 2024-10-30  Monitor  Electronics   West       Diana      2
#
#     UnitPrice  Revenue  Discount  Rating
# 17     349.99  1049.97      0.00     4.2
# 18     499.99  2999.94      0.10     3.7
# 19     399.99   799.98      0.05     4.5

# %%
print(sales.shape)
# Out:
# (20, 11)

# %%
sales.describe()
# Out:
#           OrderID                 Date      Units   UnitPrice      Revenue  \
# count    20.00000                   20  20.000000   20.000000    20.000000
# mean   1010.50000  2024-05-29 19:12:00   3.850000  529.990000  1529.961500
# min    1001.00000  2024-01-05 00:00:00   1.000000   49.990000   399.920000
# 25%    1005.75000  2024-03-18 06:00:00   2.000000  349.990000   949.987500
# 50%    1010.50000  2024-05-26 00:00:00   3.000000  449.990000  1124.970000
# 75%    1015.25000  2024-08-15 06:00:00   5.250000  624.990000  2024.970000
# max    1020.00000  2024-10-30 00:00:00  10.000000  999.990000  3499.930000
# std       5.91608                  NaN   2.518876  304.959014   866.839517
#
#         Discount     Rating
# count  20.000000  17.000000
# mean    0.062500   4.164706
# min     0.000000   3.500000
# 25%     0.000000   3.900000
# 50%     0.050000   4.200000
# 75%     0.100000   4.500000
# max     0.150000   4.800000
# std     0.053496   0.388814

# %%
print(sales.isnull().sum())
avr=sales['Rating'].mean()
sales['Rating']=sales['Rating'].fillna(avr)
print("missing after fill:",sales['Rating'].isnull().sum())
# Out:
# OrderID        0
# Date           0
# Product        0
# Category       0
# Region         0
# Salesperson    0
# Units          0
# UnitPrice      0
# Revenue        0
# Discount       0
# Rating         3
# dtype: int64
# missing after fill: 0

# %%
select=sales[['Product','Units','Revenue']]
print(select.head(8))
# Out:
#    Product  Units  Revenue
# 0   Laptop      2  1999.98
# 1    Phone      5  2499.95
# 2   Tablet      3  1049.97
# 3   Laptop      1   999.99
# 4  Monitor      2   799.98
# 5    Phone      4  1999.96
# 6   Tablet      6  2099.94
# 7   Laptop      1   999.99

# %%
g=sales[sales['Region']=='North']
print(g)
# Out:
#     OrderID       Date   Product     Category Region Salesperson  Units  \
# 0      1001 2024-01-05    Laptop  Electronics  North       Alice      2
# 4      1005 2024-03-07   Monitor  Electronics  North       Alice      2
# 8      1009 2024-05-08  Keyboard  Accessories  North       Alice     10
# 12     1013 2024-07-04    Tablet  Electronics  North       Alice      4
# 16     1017 2024-09-06  Keyboard  Accessories  North       Alice      8
#
#     UnitPrice  Revenue  Discount  Rating
# 0      999.99  1999.98      0.05     4.5
# 4      399.99   799.98      0.05     4.0
# 8       49.99   499.90      0.00     4.1
# 12     349.99  1399.96      0.00     4.7
# 16      49.99   399.92      0.00     4.0

# %%
sort=sales.sort_values('Revenue',ascending=False).head(5)
print(sort[['OrderID','Product','Region','Revenue']])
# Out:
#     OrderID Product Region  Revenue
# 10     1011   Phone   East  3499.93
# 18     1019   Phone   East  2999.94
# 1      1002   Phone  South  2499.95
# 14     1015   Phone   East  2499.95
# 6      1007  Tablet   East  2099.94

# %%
#Customers DataFrame 
customers = pd.DataFrame({
'CustomerID': range(201, 221),
'OrderID': [1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,
1011,1012,1013,1014,1015,1016,1017,1018,1019,1020],
'Name': ['Emma','Liam','Olivia','Noah','Ava','Ethan','Sophia',
'Mason','Isabella','Logan','Mia','Lucas','Charlotte',
'James','Amelia','Elijah','Harper','Oliver','Evelyn','Benjamin'],
'Age': [28,35,22,41,29,38,26,44,31,27,33,39,25,47,30,36,
23,42,28,34],
'City': ['Mumbai','Delhi','Bangalore','Chennai','Hyderabad',
'Pune','Kolkata','Ahmedabad','Jaipur','Surat',
'Mumbai','Delhi','Bangalore','Chennai','Hyderabad',
'Pune','Kolkata','Ahmedabad','Jaipur','Surat'],
'MemberType': ['Gold','Silver','Bronze','Gold','Silver','Bronze',
'Gold','Silver','Bronze','Gold','Silver','Bronze',
'Gold','Silver','Bronze','Gold','Silver','Bronze',
'Gold','Silver']
})
print("Sales shape:", sales.shape)
print("Customers shape:", customers.shape)
# Out:
# Sales shape: (20, 11)
# Customers shape: (20, 6)
